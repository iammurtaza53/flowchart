# %%
# import mysql.connector
import psycopg2
# from mysql.connector import Error
sqlCommands=[
"""INSERT INTO issue3_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:21')""",
"""INSERT INTO issue3_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:21')""",
"""INSERT INTO domain_users_password_tbl (scan_id, host,domain,"user",password, method,used, timpestamp) VALUES  ('0', '192.168.0.153', 'PROJECTX', 'sconner', 'Password1', 'TEST1', 'NO', '2022-01-11 19:11:26')""",
"""INSERT INTO domain_users_password_tbl (scan_id, host,domain,"user",password, method,used, timpestamp) VALUES  ('0', '192.168.0.153', 'PROJECTX', 'sconner', 'Password1', 'TEST1', 'NO', '2022-01-11 19:11:26')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,"user",hash, method,used, timpestamp) VALUES  ('0', '192.168.0.153', 'PROJECTX', 'sconner', '64f12cddaa88057e06a81b54e73b949b', 'TEST1', 'NO', '2022-01-11 19:11:26')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,"user",hash, method,used, timpestamp) VALUES  ('0', '192.168.0.153', 'PROJECTX', 'sconner', '64f12cddaa88057e06a81b54e73b949b', 'TEST1', 'NO', '2022-01-11 19:11:26')""",
"""INSERT INTO domain_users_password_tbl (scan_id, host,domain,"user",password, method,used, timpestamp) VALUES  ('0', '192.168.0.171', 'PROJECTX', 'jconner', 'Password1', 'sconner', 'NO', '2022-01-11 19:11:37')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,"user",hash, method,used, timpestamp) VALUES  ('0', '192.168.0.171', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'sconner', 'NO', '2022-01-11 19:11:37')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:50')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.173', '2022-01-11 19:11:50')""",
"""INSERT INTO service_1433_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_80_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_80_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.1', '2022-01-11 19:11:50')""",
"""INSERT INTO service_80_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.118', '2022-01-11 19:11:50')""",
"""INSERT INTO service_443_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.118', '2022-01-11 19:11:50')""",
"""INSERT INTO service_8080_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.102', '2022-01-11 19:11:50')""",
"""INSERT INTO service_389_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_3389_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.173', '2022-01-11 19:11:50')""",
"""INSERT INTO service_902_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.118', '2022-01-11 19:11:50')""",
"""INSERT INTO issue2_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO issue2_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO issue1_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:54')""",
"""INSERT INTO issue1_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:54')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,"user",hash, method,used, timpestamp) VALUES  ('0', '192.168.0.100', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'TEST2', 'NO', '2022-01-11 19:12:01')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,"user",hash, method,used, timpestamp) VALUES  ('0', '192.168.0.100', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'TEST2', 'NO', '2022-01-11 19:12:01')""",
"""INSERT INTO smb_details_tbl (scan_id, host,"OS",hostname,domain, signing,compromised,subnet,timpestamp) VALUES  ('0', '192.168.0.173', 'Windows 10.0 Build 17763', 'WIN-9GGB1MD1KGV', null, 'False', 'NO', '192.168.0.1', '2022-01-11 19:12:03')""",
"""INSERT INTO smb_details_tbl (scan_id, host,"OS",hostname,domain, signing,compromised,subnet,timpestamp) VALUES  ('0', '192.168.0.100', 'Windows 10.0 Build 17763', 'WIN-5307G768AU2.projectx.local', null, 'True', 'NO', '192.168.0.1', '2022-01-11 19:12:03')""",
"""INSERT INTO smb_details_tbl (scan_id, host,"OS",hostname,domain, signing,compromised,subnet,timpestamp) VALUES  ('0', '192.168.0.171', 'Windows 10.0 Build 19041', 'DESKTOP-HELQC00.projectx.local', null, 'False', 'NO', '192.168.0.1', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.153', 'test-PC.projectx.local', 'Windows 6.1 Build 7601', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.173', 'WIN-9GGB1MD1KGV', 'Windows 10.0 Build 17763', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.100', 'WIN-5307G768AU2.projectx.local', 'Windows 10.0 Build 17763', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.171', 'DESKTOP-HELQC00.projectx.local', 'Windows 10.0 Build 19041', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.150', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.1', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.192', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.126', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.111', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.152', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.102', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,"OS",subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.154', 'null', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO issue5_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:12:04')""",
"""INSERT INTO issue5_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:12:04')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue1', 'Informational', '1', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue2', 'Informational', '13', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue3', 'Informational', '4', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue4', 'Low', '1', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue5', 'High', '1', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue7', 'High', '1', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue8', 'High', '2', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue9', 'High', '2', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue11', 'Informational', '17', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue12', 'High', '1', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue13', 'High', '1', 'null', 'null', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 2, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 2, '192.168.0.100', 'PROJECTX jconner', 'TEST2', 'NA', 'NA', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 2, 'PROJECTX', 'PROJECTX jconner', 'TEST1', 'NA', 'PROJECTX', 'Domain Compromised', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 1, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 1, '192.168.0.171', 'PROJECTX jconner', 'LATERAL', 'sconner', 'NA', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 1, 'PROJECTX', 'PROJECTX jconner', 'TEST1', 'NA', 'PROJECTX', 'Domain Compromised', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 3, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 3, '192.168.0.171', 'PROJECTX jconner', 'LATERAL', 'sconner', 'NA', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 3, 'PROJECTX', 'PROJECTX jconner', 'TEST1', 'NA', 'PROJECTX', 'Domain Compromised', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 4, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'issue6 desc', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 4, '192.168.0.100', 'projectx.local Administrator', 'issue5_tbl', 'NA', 'NA', 'issue5_tbl description', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,"compromisedUser",method,"user",domain,relationship,timpestamp) VALUES  ('0', 4, 'projectx.local', 'projectx.local Administrator', 'TEST1', 'NA', 'projectx.local', 'Domain Compromised', '2022-01-11 19:12:07')"""]
try:
    connection = psycopg2.connect(host='ec2-54-224-64-114.compute-1.amazonaws.com',
                                         database='d3il9istve5iba',
                                         user='acsdeorgfmjeap',
                                    password='59acf03ca46305a502c2d502f420145ee3c8669d45546e34f10fc48522d4f302',
                                 port='5432')
    if connection:
#         db_Info = connection.get_server_info()
#         print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        for command in sqlCommands:
            cursor.execute(command)

        connection.commit()
#         print("connected sucessfully")
        print(cursor.rowcount, "record inserted.")
       

except psycopg2.Error as e:
    print("Error while connecting to MySQL", e)
# finally:
#     if connection.is_connected():
#         cursor.close()
#         connection.close()
#         print("MySQL connection is closed")
# Out:
# 1 record inserted.

# %%
sqlCommands=["""INSERT INTO domain_users_password_tbl (scan_id, host,domain,user,password, method,used, timpestamp) VALUES  ('0', '192.168.0.171', 'PROJECTX', 'jconner', 'Password1', 'sconner', 'NO', '2022-01-11 19:11:37')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,user,hash, method,used, timpestamp) VALUES  ('0', '192.168.0.171', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'sconner', 'NO', '2022-01-11 19:11:37')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:50')""",
"""INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.173', '2022-01-11 19:11:50')""",
"""INSERT INTO service_1433_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_80_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_80_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.1', '2022-01-11 19:11:50')""",
"""INSERT INTO service_80_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.118', '2022-01-11 19:11:50')""",
"""INSERT INTO service_443_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.118', '2022-01-11 19:11:50')""",
"""INSERT INTO service_8080_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.102', '2022-01-11 19:11:50')""",
"""INSERT INTO service_389_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_3389_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:50')""",
"""INSERT INTO service_135_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.173', '2022-01-11 19:11:50')""",
"""INSERT INTO service_902_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.118', '2022-01-11 19:11:50')""",
"""INSERT INTO issue2_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO issue2_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')""",
"""INSERT INTO issue1_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:54')""",
"""INSERT INTO issue1_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:54')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,user,hash, method,used, timpestamp) VALUES  ('0', '192.168.0.100', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'TEST2', 'NO', '2022-01-11 19:12:01')""",
"""INSERT INTO domain_users_hash_tbl (scan_id, host,domain,user,hash, method,used, timpestamp) VALUES  ('0', '192.168.0.100', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'TEST2', 'NO', '2022-01-11 19:12:01')""",
"""INSERT INTO smb_details_tbl (scan_id, host,OS,hostname,domain, signing,compromised,subnet,timpestamp) VALUES  ('0', '192.168.0.173', 'Windows 10.0 Build 17763', 'WIN-9GGB1MD1KGV', None, 'False', 'NO', '192.168.0.1', '2022-01-11 19:12:03')""",
"""INSERT INTO smb_details_tbl (scan_id, host,OS,hostname,domain, signing,compromised,subnet,timpestamp) VALUES  ('0', '192.168.0.100', 'Windows 10.0 Build 17763', 'WIN-5307G768AU2.projectx.local', None, 'True', 'NO', '192.168.0.1', '2022-01-11 19:12:03')""",
"""INSERT INTO smb_details_tbl (scan_id, host,OS,hostname,domain, signing,compromised,subnet,timpestamp) VALUES  ('0', '192.168.0.171', 'Windows 10.0 Build 19041', 'DESKTOP-HELQC00.projectx.local', None, 'False', 'NO', '192.168.0.1', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.153', 'test-PC.projectx.local', 'Windows 6.1 Build 7601', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.173', 'WIN-9GGB1MD1KGV', 'Windows 10.0 Build 17763', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.100', 'WIN-5307G768AU2.projectx.local', 'Windows 10.0 Build 17763', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.171', 'DESKTOP-HELQC00.projectx.local', 'Windows 10.0 Build 19041', '192.168.0.1', 'YES', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.150', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.1', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.192', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.126', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.111', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.152', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.102', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO final_hosts_tbl (scan_id, host,hostname,OS,subnet,compromised,timpestamp) VALUES  ('0', '192.168.0.154', 'None', 'UNIX', '192.168.0.1', 'NO', '2022-01-11 19:12:03')""",
"""INSERT INTO issue5_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:12:04')""",
"""INSERT INTO issue5_tbl (scan_id, host,timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:12:04')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue1', 'Informational', '1', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue2', 'Informational', '13', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue3', 'Informational', '4', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue4', 'Low', '1', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue5', 'High', '1', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue7', 'High', '1', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue8', 'High', '2', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue9', 'High', '2', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue11', 'Informational', '17', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue12', 'High', '1', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO findings_tbl (scan_id, name,risk,count,attackmitre,sia,timpestamp) VALUES  ('0', 'issue13', 'High', '1', 'None', 'None', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 2, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 2, '192.168.0.100', 'PROJECTX jconner', 'TEST2', 'NA', 'NA', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 2, 'PROJECTX', 'PROJECTX jconner', 'TEST1', 'NA', 'PROJECTX', 'Domain Compromised', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 1, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 1, '192.168.0.171', 'PROJECTX jconner', 'LATERAL', 'sconner', 'NA', "test", '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 1, 'PROJECTX', 'PROJECTX jconner', 'TEST1', 'NA', 'PROJECTX', 'Domain Compromised', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 3, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'test', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 3, '192.168.0.171', 'PROJECTX jconner', 'LATERAL', 'sconner', 'NA', "test", '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 3, 'PROJECTX', 'PROJECTX jconner', 'TEST1', 'NA', 'PROJECTX', 'Domain Compromised', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 4, '192.168.0.153', 'PROJECTX sconner', 'TEST1', 'NA', 'PROJECTX', 'issue6 desc', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 4, '192.168.0.100', 'projectx.local Administrator', 'issue5_tbl', 'NA', 'NA', 'issue5_tbl description', '2022-01-11 19:12:07')""",
"""INSERT INTO paths_tbl (scan_id, pathid,host,compromisedUser,method,user,domain,relationship,timpestamp) VALUES  ('0', 4, 'projectx.local', 'projectx.local Administrator', 'TEST1', 'NA', 'projectx.local', 'Domain Compromised', '2022-01-11 19:12:07')"""]
     
for c in sqlCommands:
    print (c)
# Out:
# INSERT INTO domain_users_password_tbl (scan_id, host,domain,user,password, method,used, timpestamp) VALUES  ('0', '192.168.0.171', 'PROJECTX', 'jconner', 'Password1', 'sconner', 'NO', '2022-01-11 19:11:37')
# INSERT INTO domain_users_hash_tbl (scan_id, host,domain,user,hash, method,used, timpestamp) VALUES  ('0', '192.168.0.171', 'PROJECTX', 'jconner', '64f12cddaa88057e06a81b54e73b949b', 'sconner', 'NO', '2022-01-11 19:11:37')
# INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.100', '2022-01-11 19:11:50')
# INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')
# INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.153', '2022-01-11 19:11:50')
# INSERT INTO service_445_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.173', '2022-01-11 19:11:50')
# INSERT INTO service_1433_tbl (scan_id, host, timpestamp) VALUES ('0', '192.168.0.171', '2022-01-11 19:11:50')
# ...
